# %% [markdown]
# <a href="https://colab.research.google.com/github/rogerio-stubs/Python-Algorithms/blob/master/URI_Iniciante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1013 - Maior valor
valueList = []
a, b, c = input().split()
x = int(a)
y = int(b)
z = int(c)
valueList.append(x)
valueList.append(y)
valueList.append(z)
print(max(valueList), 'eh o maior')

# %%
#1004 - Produto simples
x = int(input())
y = int(input())
prod = x * y
print('PROD =', prod)
